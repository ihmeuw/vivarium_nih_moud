# %%
# %reload_ext autoreload
# %autoreload 2
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from vivarium import InteractiveContext

# %%
# !cat ../src/vivarium_nih_moud/model_specifications/model_spec.yaml
# Out:
# components:
#     vivarium_public_health.population:
#         - BasePopulation()
#         - Mortality()
#     vivarium_nih_moud.components:
#         - conditions.moud_model()
#         - locations.quarters_model()
#         - locations.quarters_risk()
#         - locations.SimpleRiskEffect('quarters_risk',
#                 'oud_consistent_to_on_treatment_for_oud_consistent.transition_rate')
#     vivarium_public_health.results:
#         - ResultsStratifier()
#         - DisabilityObserver()
#         - DiseaseObserver('oud_consistent')
#         - DiseaseObserver('quarters')
#         - MortalityObserver()
#
# configuration:
#     input_data:
#         input_draw_number: 0
#         artifact_path: /home/abie/vivarium_nih_moud/washington.hdf
#         # artifact_path: /mnt/team/simulation_science/pub/training/abie/artifacts/washington.hdf
#
#     interpolation:
#         order: 0
#         extrapolate: True
#     randomness:
#         map_size: 1_000_000
#         key_columns: ['entrance_time', 'age']
#         random_seed: 4344
#         additional_seed: 169
#     time:
#         start:
#             year: 2019
#             month: 1
#             day: 1
#         end:
#             year: 2040
#             month: 1
#             day: 1
#         step_size: 182 # Days
#     population:
#         population_size: 100_000
#         initialization_age_min: 0
#         initialization_age_max: 50
#         untracking_age: 100
#     oud_consistent:
#         exposure: 0.016, # HACK: this should not be used, nor necessary
#         state_to_risk_category_map:
#             oud_consistent: cat1
#             susceptible_to_oud_consistent: cat2
#             on_treatment_for_oud_consistent : cat2
#     quarters:
#         state_to_risk_category_map:
#             unhoused: cat1
#             incarcerated: cat2
#             housed : cat3
#
#
#     stratification:
#         default:
#             - 'age_group'
#             - 'sex'
#             - 'current_year'
#         # disability:
#         #     include:
#         #     exclude:
#         # mortality:
#         #     include:
#         #     exclude:
#         oud_consistent:
#             include:
#                 - 'quarters'
#         quarters:
#             include:
#                 - 'oud_consistent'

# %%
sim = InteractiveContext('../src/vivarium_nih_moud/model_specifications/model_spec.yaml')
# Out:
# 2025-05-05 17:16:34.991 | INFO     | simulation_4-artifact_manager:77 - Running simulation from artifact located at /home/abie/vivarium_nih_moud/washington.hdf.
# 2025-05-05 17:16:34.992 | INFO     | simulation_4-artifact_manager:78 - Artifact base filter terms are ['draw == 0'].
# 2025-05-05 17:16:34.994 | INFO     | simulation_4-artifact_manager:79 - Artifact additional filter terms are None.
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium_public_health/population/data_transformations.py:57: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   .apply(lambda sub_pop: sub_pop[["value"]] / sub_pop["value"].sum())
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium_public_health/population/data_transformations.py:64: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   .apply(lambda sub_pop: sub_pop[["value"]] / sub_pop["value"].sum())
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium_public_health/population/data_transformations.py:71: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   .apply(lambda sub_pop: sub_pop[["value"]] / sub_pop["value"].sum())
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# 2025-05-05 17:16:36.856 | WARNING  | simulation_4-resource_manager:176 - Resource stream.oud_consistent_initial_states is not produced by any component but is needed to compute (column.oud_consistent).
# 2025-05-05 17:16:36.857 | WARNING  | simulation_4-resource_manager:176 - Resource stream.quarters_initial_states is not produced by any component but is needed to compute (column.quarters).
# 2025-05-05 17:16:36.857 | WARNING  | simulation_4-resource_manager:176 - Resource column.quarters_risk is not produced by any component but is needed to compute (value_modifier.oud_consistent_to_on_treatment_for_oud_consistent.transition_rate.1.simple_risk_effect.oud_consistent_to_on_treatment_for_oud_consistent.transition_rate.apply_risk_effect).
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:72: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(self.data.groupby(list(self.categorical_parameters)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:240: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(data.groupby(list(other_params)))
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(

# %%
pop0 = sim.get_population()
pop0
# Out:
#        tracked    location     sex        age entrance_time  alive exit_time  \
# 0         True  Washington  Female  16.939163    2018-07-03  alive       NaT
# 1         True  Washington  Female  39.958889    2018-07-03  alive       NaT
# 2         True  Washington    Male  21.926816    2018-07-03  alive       NaT
# 3         True  Washington  Female   4.568871    2018-07-03  alive       NaT
# 4         True  Washington  Female  34.515565    2018-07-03  alive       NaT
# ...        ...         ...     ...        ...           ...    ...       ...
# 99995     True  Washington  Female  26.810172    2018-07-03  alive       NaT
# 99996     True  Washington  Female   4.808079    2018-07-03  alive       NaT
# 99997     True  Washington    Male  33.478481    2018-07-03  alive       NaT
# 99998     True  Washington  Female   2.588977    2018-07-03  alive       NaT
# 99999     True  Washington    Male  37.052429    2018-07-03  alive       NaT
#
#       cause_of_death  years_of_life_lost                 oud_consistent  ...  \
# 0           not_dead                 0.0  susceptible_to_oud_consistent  ...
# 1           not_dead                 0.0  susceptible_to_oud_consistent  ...
# 2           not_dead                 0.0  susceptible_to_oud_consistent  ...
# 3           not_dead                 0.0  susceptible_to_oud_consistent  ...
# 4           not_dead                 0.0                 oud_consistent  ...
# ...              ...                 ...                            ...  ...
# 99995       not_dead                 0.0  susceptible_to_oud_consistent  ...
# 99996       not_dead                 0.0  susceptible_to_oud_consistent  ...
# 99997       not_dead                 0.0  susceptible_to_oud_consistent  ...
# 99998       not_dead                 0.0  susceptible_to_oud_consistent  ...
# 99999       not_dead                 0.0  susceptible_to_oud_consistent  ...
#
#       on_treatment_for_oud_consistent_event_count  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 99995                                           0
# 99996                                           0
# 99997                                           0
# 99998                                           0
# 99999                                           0
#
#       on_treatment_for_oud_consistent_event_time  \
# 0                                            NaT
# 1                                            NaT
# 2                                            NaT
# 3                                            NaT
# 4                                            NaT
# ...                                          ...
# 99995                                        NaT
# 99996                                        NaT
# 99997                                        NaT
# 99998                                        NaT
# 99999                                        NaT
#
#              previous_oud_consistent  housed_event_count housed_event_time  \
# 0      susceptible_to_oud_consistent                   0               NaT
# 1      susceptible_to_oud_consistent                   0               NaT
# 2      susceptible_to_oud_consistent                   0               NaT
# 3      susceptible_to_oud_consistent                   0               NaT
# 4                     oud_consistent                   0               NaT
# ...                              ...                 ...               ...
# 99995  susceptible_to_oud_consistent                   0               NaT
# 99996  susceptible_to_oud_consistent                   0               NaT
# 99997  susceptible_to_oud_consistent                   0               NaT
# 99998  susceptible_to_oud_consistent                   0               NaT
# 99999  susceptible_to_oud_consistent                   0               NaT
#
#        unhoused_event_count unhoused_event_time incarcerated_event_count  \
# 0                         0                 NaT                        0
# 1                         0                 NaT                        0
# 2                         0                 NaT                        0
# 3                         0                 NaT                        0
# 4                         0                 NaT                        0
# ...                     ...                 ...                      ...
# 99995                     0                 NaT                        0
# 99996                     0                 NaT                        0
# 99997                     0                 NaT                        0
# 99998                     0                 NaT                        0
# 99999                     0                 NaT                        0
#
#        incarcerated_event_time previous_quarters
# 0                          NaT            housed
# 1                          NaT            housed
# 2                          NaT            housed
# 3                          NaT            housed
# 4                          NaT            housed
# ...                        ...               ...
# 99995                      NaT            housed
# 99996                      NaT            housed
# 99997                      NaT            housed
# 99998                      NaT            housed
# 99999                      NaT            housed
#
# [100000 rows x 25 columns]

# %%
pop0.oud_consistent.value_counts()
# Out:
# susceptible_to_oud_consistent      97584
# oud_consistent                      1975
# on_treatment_for_oud_consistent      441
# Name: oud_consistent, dtype: int64

# %%
pop0.quarters.value_counts()
# Out:
# housed    100000
# Name: quarters, dtype: int64

# %%
sim.step()
# Out:
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(

# %%
pop1 = sim.get_population()

# %%
pop1.oud_consistent.value_counts()
# Out:
# susceptible_to_oud_consistent      97594
# oud_consistent                      1830
# on_treatment_for_oud_consistent      576
# Name: oud_consistent, dtype: int64

# %%
pop1.quarters.value_counts()
# Out:
# housed          91280
# incarcerated     4541
# unhoused         4179
# Name: quarters, dtype: int64

# %%
pd.crosstab(pop0.oud_consistent, pop0.quarters, margins=True)
# Out:
# quarters                         housed     All
# oud_consistent
# on_treatment_for_oud_consistent     441     441
# oud_consistent                     1975    1975
# susceptible_to_oud_consistent     97584   97584
# All                              100000  100000

# %%
np.round(100*pd.crosstab(pop1.oud_consistent, pop1.quarters, margins=True, normalize='index'), 1)
# Out:
# quarters                         housed  incarcerated  unhoused
# oud_consistent
# on_treatment_for_oud_consistent    91.1           4.9       4.0
# oud_consistent                     90.7           4.6       4.7
# susceptible_to_oud_consistent      91.3           4.5       4.2
# All                                91.3           4.5       4.2

# %%
np.round(100*pd.crosstab(pop1.quarters, pop1.oud_consistent, margins=True, normalize='index'), 1)
# Out:
# oud_consistent  on_treatment_for_oud_consistent  oud_consistent  \
# quarters
# housed                                      0.6             1.8
# incarcerated                                0.6             1.9
# unhoused                                    0.6             2.1
# All                                         0.6             1.8
#
# oud_consistent  susceptible_to_oud_consistent
# quarters
# housed                                   97.6
# incarcerated                             97.5
# unhoused                                 97.4
# All                                      97.6

# %% [markdown]
# # Goal: induce corelation between quarters and oud state
#
# Approach: follow pattern similar to the Risk and RiskEffect models.

# %%
sim.step()
# Out:
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(
# /home/abie/miniforge3/envs/vivarium_nih_moud_simulation/lib/python3.11/site-packages/vivarium/framework/lookup/interpolation.py:114: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   sub_tables = list(

# %%
pop2 = sim.get_population()

# %%
t = pd.concat([pop0, pop1, pop2], axis=1).filter(like='quarters')
t[t.iloc[:, 2] != 'housed']
# Out:
#       quarters previous_quarters      quarters previous_quarters  \
# 3       housed            housed  incarcerated            housed
# 20      housed            housed      unhoused            housed
# 23      housed            housed  incarcerated            housed
# 33      housed            housed  incarcerated            housed
# 48      housed            housed      unhoused            housed
# ...        ...               ...           ...               ...
# 99907   housed            housed      unhoused            housed
# 99924   housed            housed  incarcerated            housed
# 99952   housed            housed      unhoused            housed
# 99979   housed            housed  incarcerated            housed
# 99984   housed            housed      unhoused            housed
#
#            quarters previous_quarters
# 3          unhoused      incarcerated
# 20     incarcerated          unhoused
# 23     incarcerated      incarcerated
# 33           housed      incarcerated
# 48         unhoused          unhoused
# ...             ...               ...
# 99907  incarcerated          unhoused
# 99924      unhoused      incarcerated
# 99952  incarcerated          unhoused
# 99979  incarcerated      incarcerated
# 99984      unhoused          unhoused
#
# [8720 rows x 6 columns]

# %%
[x for x in sim.list_values() if 'expo' in x]
# Out:
# ['quarters_risk.exposure']

# %%
# %cd /home/abie/vivarium_results/washington/2025_05_05_12_20_15/results
# !ls -halt

# %%
# pd.read_parquet('deaths.parquet').sort_values('value', ascending=False)

# %%
# pd.read_parquet('ylls.parquet').sort_values('value', ascending=False)

# %%
# pd.read_parquet('transition_count_oud_consistent.parquet').sort_values('value')

# %%
# pd.read_parquet('transition_count_quarters.parquet').sort_values('value')

# %%
# pd.read_parquet('person_time_quarters.parquet').sort_values('value')

# %%
# pd.read_parquet('person_time_oud_consistent.parquet').sort_values('value')

# %%
# pd.read_parquet('ylds.parquet').sort_values('value')
